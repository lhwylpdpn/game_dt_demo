# %%
#解析生成json的内容
#解析决策过程的日志
import os
import json
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

def paese_result_json(log_path):
    #读取json文件
    res=json.load(open(log_path,"r"))['update']
    #去除掉init_state部分
    static={}
    for r in res:
        actions,states,tick=r['action'],r['state'],r['tick']
        
        for action in actions:
            if str(action['class']) + '_' + str(action['id']) not in static:
                static[str(action['class']) + '_' + str(action['id'])]={}
            static[str(action['class']) + '_' + str(action['id'])][action['action_type']]=static[str(action['class']) + '_' + str(action['id'])][action['action_type']]+1 if action['action_type'] in static[str(action['class']) + '_' + str(action['id'])] else 1
            if 'damage' not in static[str(action['class']) + '_' + str(action['id'])]:
                static[str(action['class']) + '_' + str(action['id'])]['damage']=[]
            #print(action['class'] + '_' + str(action['id']),static[str(action['class']) + '_' + str(action['id'])]['damage'])

            if 'damage' in action:
                for damage in action['damage']:
                    static[str(action['class']) + '_' + str(action['id'])]['damage'].append(damage[1][0])                         
            
                        
            
            if 'effects' not in static[str(action['class']) + '_' + str(action['id'])]:
                static[str(action['class']) + '_' + str(action['id'])]['effects']=[]

                        
#             if action['class'] + '_' + str(action['id'])=='monster_716666':
#                 print('77777', action['class'] + '_' + str(action['id']))
            
                
            if 'effects' in action:
                if len(action['effects'])>0:
                    for r in action['effects']:
                        static[str(action['class']) + '_' + str(action['id'])]['effects'].append(r[1])
        for state in states:
            if len(state)>0:
                for change in state:
                    if change[1][2]=="Hp":
                        #pass
                        if str(change[1][0]) + '_' + str(change[1][1]) not in static:
                            static[str(change[1][0]) + '_' + str(change[1][1])]={}
                        
                        if '最终HP' not in static[str(change[1][0]) + '_' + str(change[1][1])]:
                            static[str(change[1][0]) + '_' + str(change[1][1])]['最终HP']=''
                        static[str(change[1][0]) + '_' + str(change[1][1])]['最终HP']=change[2][1]

    for k in static.keys():
        if 'damage' not in static[k]:
            static[k]['damage']=[]
        if 'effects' not in static[k]:
            static[k]['effects']=[]
        static[k]['总伤害']=sum(static[k]['damage'])
        static[k]['总伤害次数']=len(static[k]['damage'])
        static[k]['平均伤害']=sum(static[k]['damage'])/len(static[k]['damage']) if len(static[k]['damage'])>0 else 0
        static[k]['各类效果']= list(set(num for sublist in static[k]['effects'] for num in sublist))
        if 'RIGHT' not in static[k]:
            static[k]['RIGHT']=0
        if 'LEFT' not in static[k]:
            static[k]['LEFT']=0
        if 'TOP' not in static[k]:
            static[k]['TOP']=0
        if 'BOTTOM' not in static[k]:
            static[k]['BOTTOM']=0
        static[k]['总移动次数']=static[k]['RIGHT']+static[k]['LEFT']+static[k]['TOP']+static[k]['BOTTOM']
        
        
        #隐藏具体伤害
        static[k].pop('damage')
        static[k].pop('effects')

        #按照key 排序
        static[k]=dict(sorted(static[k].items(),key=lambda x:x[0]))
    print('总tick',res[-1]['tick'])
    return static

# %%
log_files_path = os.getcwd()+"/test_data"
    #读取这个路径下所有文件
log_files = os.listdir(log_files_path)
for log_file in log_files:
    if log_file.endswith(".json"):
        log_path = log_files_path+"/"+log_file
        static_res_json=paese_result_json(log_path)
        df=pd.DataFrame(static_res_json).T
        display(df)
# Out:
# 总tick 448
#                  BOTTOM LEFT MOVE_START RIGHT TOP WAIT          各类效果  \
# monster_16714666      0    0         20     0   0   20            []
# monster_616666        6    1         17     8   3  NaN  [65, 67, 78]
# monster_1316666       5    5         16     9   3    2  [65, 67, 78]
# monster_7115666       0    0         20     0   0   20            []
# hero_5003             4    8         16    17   8  NaN            []
# monster_716666        4    1          8     8   3  NaN      [65, 67]
# hero_5001             5    2         13    16   6    2            []
# hero_5002             2    7         12    17   7  NaN            []
# monster_13713666      0    0         12     0   0   12            []
# monster_13712666      0    0         12     0   0   12            []
# monster_8115666       0    0         12     0   0   12            []
# monster_1216666       4    3          8     9   3    1      [65, 67]
# monster_1416666       6    2          9     6   3    2  [65, 67, 78]
# monster_6115666       0    0         12     0   0   12            []
# monster_516666        3    0          5    11   1  NaN  [65, 67, 78]
#
#                        平均伤害   总伤害 总伤害次数 总移动次数 SKILL_77 最终HP SKILL_87 SKILL_88  \
# monster_16714666          0     0     0     0      NaN  NaN      NaN      NaN
# monster_616666          0.0     0    11    18       11    0      NaN      NaN
# monster_1316666         0.0     0    13    22       13    0      NaN      NaN
# monster_7115666           0     0     0     0      NaN  NaN      NaN      NaN
# hero_5003         84.866667  1273    15    37      NaN  NaN        2        4
# monster_716666          0.0     0     7    16      NaN    0      NaN      NaN
# hero_5001         62.538462   813    13    29      NaN  NaN      NaN      NaN
# hero_5002              61.6   616    10    33      NaN  NaN      NaN      NaN
# monster_13713666          0     0     0     0      NaN  NaN      NaN      NaN
# monster_13712666          0     0     0     0      NaN  NaN      NaN      NaN
# monster_8115666           0     0     0     0      NaN  NaN      NaN      NaN
# monster_1216666         0.0     0     7    19      NaN    0      NaN      NaN
# monster_1416666         0.0     0     7    17      NaN    0      NaN      NaN
# monster_6115666           0     0     0     0      NaN  NaN      NaN      NaN
# monster_516666          0.0     0     5    15      NaN    0      NaN      NaN
#
#                  SKILL_89 SKILL_90 SKILL_137 EFFECT_64 SKILL_100 SKILL_96  \
# monster_16714666      NaN      NaN       NaN       NaN       NaN      NaN
# monster_616666        NaN      NaN       NaN       NaN       NaN      NaN
# monster_1316666       NaN      NaN       NaN       NaN       NaN      NaN
# monster_7115666       NaN      NaN       NaN       NaN       NaN      NaN
# hero_5003               4        4       NaN       NaN       NaN      NaN
# monster_716666        NaN      NaN         7       NaN       NaN      NaN
# hero_5001             NaN      NaN       NaN        13         4        7
# hero_5002             NaN      NaN       NaN        12       NaN      NaN
# monster_13713666      NaN      NaN       NaN       NaN       NaN      NaN
# monster_13712666      NaN      NaN       NaN       NaN       NaN      NaN
# monster_8115666       NaN      NaN       NaN       NaN       NaN      NaN
# monster_1216666       NaN      NaN         7       NaN       NaN      NaN
# monster_1416666       NaN      NaN         7       NaN       NaN      NaN
# monster_6115666       NaN      NaN       NaN       NaN       NaN      NaN
# monster_516666        NaN      NaN         5       NaN       NaN      NaN
#
#                  SKILL_78 SKILL_80
# monster_16714666      NaN      NaN
# monster_616666        NaN      NaN
# monster_1316666       NaN      NaN
# monster_7115666       NaN      NaN
# hero_5003             NaN      NaN
# monster_716666        NaN      NaN
# hero_5001             NaN      NaN
# hero_5002               1        9
# monster_13713666      NaN      NaN
# monster_13712666      NaN      NaN
# monster_8115666       NaN      NaN
# monster_1216666       NaN      NaN
# monster_1416666       NaN      NaN
# monster_6115666       NaN      NaN
# monster_516666        NaN      NaN

# %%
def parse_result_json_detail(log_path):
    res = json.load(open(log_path, "r"))['update']
    # 去除掉init_state部分
    static = {}
    for r in res:
        actions,states,tick=r['action'],r['state'],r['tick']
        for i in range(len(actions)):
            if actions[i]['id']==16714666:
                if actions[i]['action_type']!='MOVE_START' and actions[i]['action_type']!='WAIT':
                    print(actions[i],states[i],r['tick'])
log_files_path = os.getcwd() + "/test_data"
    # 读取这个路径下所有文件
log_path = log_files_path + "/for_qiangye_skill_"+str(99)+".json"
log_path = log_files_path + "/for_qiangye.json"

parse_result_json_detail(log_path)

# %%
def parse_decision_log(log_path):
    res=json.load(open(log_path,"r"))
    for k,v in res.items():
        if 'stepname' in v:
            if 'hero' in v:
                if v['hero']==5001:
                    if 'evaluate' in v['stepname'] or '决策树' in v['stepname']:
                        if  v['stepname']=='决策树-首次查找最终选择' or  v['stepname']=='决策树-多次查找最终选择':
                            #if '判断是否满足恢复判定' in v['selection'] and v['result_len']=='True':
                                print(k,v)
                        
def static_decision_log(log_path):
    static={}
    res=json.load(open(log_path,"r"))
    for k,v in res.items():
        if 'stepname' in v:
            if 'evaluate' in v['stepname'] or '决策树' in v['stepname']:
                if  v['stepname']=='决策树-首次查找最终选择' and v['result_len']!=0:
                    if v['hero'] not in static:
                        static[v['hero']]={}
                    if v['action'] not in static[v['hero']]:
                        static[v['hero']][v['action']]=1
                    static[v['hero']][v['action']]=static[v['hero']][v['action']]+1
                    
                if  v['stepname']=='决策树-多次查找最终选择':
                    if v['hero'] not in static:
                        static[v['hero']]={}
                    if v['action'] not in static[v['hero']]:
                        static[v['hero']][v['action']]=1
                    static[v['hero']][v['action']]=static[v['hero']][v['action']]+1
                if v['stepname']=='决策树-偏好决策':
                    if v['hero'] not in static:
                        static[v['hero']]={}
                    if v['action'] not in static[v['hero']]:
                        static[v['hero']]['偏好_'+str(v['action'])]=1
                    static[v['hero']]['偏好_'+str(v['action'])]=static[v['hero']]['偏好_'+str(v['action'])]+1

    df=pd.DataFrame(static).T
    display(df)

# %%
#统计情况
static_decision_log(os.getcwd()+"/../log/logs_temp.json")
# Out:
#           偏好_等待    等待  移动到敌人附近  移动到敌人附近并攻击  偏好_p_0_action  移动到boss
# 16714666   21.0  21.0      NaN         NaN            NaN      NaN
# 616666      2.0   NaN      7.0        12.0            NaN      NaN
# 1316666    17.0   3.0      2.0        14.0            NaN      NaN
# 7115666    21.0  21.0      NaN         NaN            NaN      NaN
# 5003        2.0   NaN      NaN         5.0            2.0      3.0
# 5001        3.0   3.0      NaN        12.0            NaN      NaN
# 5002        2.0   NaN      NaN        11.0            NaN      3.0
# 13713666   13.0  13.0      NaN         NaN            NaN      NaN
# 13712666   13.0  13.0      NaN         NaN            NaN      NaN
# 8115666    13.0  13.0      NaN         NaN            NaN      NaN
# 1216666     9.0   2.0      NaN         8.0            NaN      NaN
# 1416666    10.0   3.0      NaN         8.0            NaN      NaN
# 6115666    13.0  13.0      NaN         NaN            NaN      NaN
# 516666      2.0   NaN      NaN         6.0            NaN      NaN
# 716666      2.0   NaN      2.0         8.0            NaN      NaN

# %%
tmp_log_file = os.getcwd()+"/../log/logs_temp.json"
parse_decision_log(tmp_log_file)
# Out:
# 2024-10-08 15:06:50.553438_77 {'stepname': '决策树-偏好决策', 'result_len': 0, 'action': '等待', 'hero': 5001}
# 2024-10-08 15:06:50.620037_84 {'stepname': '决策树-首次查找最终选择', 'result_len': 4, 'action': '移动到敌人附近并攻击', 'hero': 5001}
# 2024-10-08 15:06:55.768892_323 {'stepname': '决策树-偏好决策', 'result_len': 0, 'action': '等待', 'hero': 5001}
# 2024-10-08 15:06:55.985158_330 {'stepname': '决策树-首次查找最终选择', 'result_len': 4, 'action': '移动到敌人附近并攻击', 'hero': 5001}
# 2024-10-08 15:07:06.345494_637 {'stepname': '决策树-偏好决策', 'result_len': 0, 'action': '等待', 'hero': 5001}
# 2024-10-08 15:07:06.692506_644 {'stepname': '决策树-首次查找最终选择', 'result_len': 4, 'action': '移动到敌人附近并攻击', 'hero': 5001}
# 2024-10-08 15:07:18.025478_891 {'stepname': '决策树-偏好决策', 'result_len': 0, 'action': '等待', 'hero': 5001}
# 2024-10-08 15:07:18.382394_898 {'stepname': '决策树-首次查找最终选择', 'result_len': 4, 'action': '移动到敌人附近并攻击', 'hero': 5001}
# 2024-10-08 15:07:35.395555_1205 {'stepname': '决策树-偏好决策', 'result_len': 0, 'action': '等待', 'hero': 5001}
# 2024-10-08 15:07:35.730609_1212 {'stepname': '决策树-首次查找最终选择', 'result_len': 4, 'action': '移动到敌人附近并攻击', 'hero': 5001}
# 2024-10-08 15:07:52.722214_1468 {'stepname': '决策树-偏好决策', 'result_len': 0, 'action': '等待', 'hero': 5001}
# 2024-10-08 15:07:53.143431_1475 {'stepname': '决策树-首次查找最终选择', 'result_len': 4, 'action': '移动到敌人附近并攻击', 'hero': 5001}
# 2024-10-08 15:08:13.789285_1745 {'stepname': '决策树-偏好决策', 'result_len': 0, 'action': '等待', 'hero': 5001}
# 2024-10-08 15:08:14.280671_1752 {'stepname': '决策树-首次查找最终选择', 'result_len': 3, 'action': '移动到敌人附近并攻击', 'hero': 5001}
# 2024-10-08 15:08:33.043097_1973 {'stepname': '决策树-偏好决策', 'result_len': 0, 'action': '等待', 'hero': 5001}
# 2024-10-08 15:08:33.592838_1980 {'stepname': '决策树-首次查找最终选择', 'result_len': 4, 'action': '移动到敌人附近并攻击', 'hero': 5001}
# 2024-10-08 15:08:57.668425_2238 {'stepname': '决策树-偏好决策', 'result_len': 0, 'action': '等待', 'hero': 5001}
# 2024-10-08 15:08:58.299091_2245 {'stepname': '决策树-首次查找最终选择', 'result_len': 3, 'action': '移动到敌人附近并攻击', 'hero': 5001}
# 2024-10-08 15:09:09.417359_2350 {'stepname': '决策树-偏好决策', 'result_len': 0, 'action': '等待', 'hero': 5001}
# 2024-10-08 15:09:10.065613_2357 {'stepname': '决策树-首次查找最终选择', 'result_len': 3, 'action': '移动到敌人附近并攻击', 'hero': 5001}
# 2024-10-08 15:09:36.119798_2602 {'stepname': '决策树-偏好决策', 'result_len': 0, 'action': '等待', 'hero': 5001}
# 2024-10-08 15:09:36.820230_2609 {'stepname': '决策树-首次查找最终选择', 'result_len': 3, 'action': '移动到敌人附近并攻击', 'hero': 5001}
# 2024-10-08 15:09:55.103613_2764 {'stepname': '决策树-偏好决策', 'result_len': 0, 'action': '等待', 'hero': 5001}
# 2024-10-08 15:09:56.013283_2772 {'stepname': '决策树-首次查找最终选择', 'result_len': 0, 'action': '移动到boss', 'hero': 5001}
# 2024-10-08 15:09:56.350689_2775 {'stepname': '决策树-多次查找最终选择', 'result_len': 1, 'action': '等待', 'hero': 5001}
# 2024-10-08 15:10:16.946029_2943 {'stepname': '决策树-偏好决策', 'result_len': 0, 'action': '等待', 'hero': 5001}
# 2024-10-08 15:10:17.934969_2951 {'stepname': '决策树-首次查找最终选择', 'result_len': 0, 'action': '移动到boss', 'hero': 5001}
# 2024-10-08 15:10:18.272609_2954 {'stepname': '决策树-多次查找最终选择', 'result_len': 1, 'action': '等待', 'hero': 5001}
